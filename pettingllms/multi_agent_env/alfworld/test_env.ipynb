# %%
from alfworld.agents.environment.alfred_tw_env import AlfredTWEnv
from pettingllms.multi_agent_env.alfworld.utils import load_config_file

# %%
config = load_config_file()
#env_type = config['env']['type']
base_env = AlfredTWEnv(config, train_eval='train')
# Out:
# Initializing AlfredTWEnv...
# 0it [00:00, ?it/s]
# Overall we have 0 games in split=train
# Training with 0 games

# %%
env=base_env.init_env(batch_size=1)
env.seed(0)
env.get_observation()
env.get_admissible_actions()
# Out:
# [0]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 base_env.seed(0)
#
# AttributeError: 'AlfredTWEnv' object has no attribute 'seed'
